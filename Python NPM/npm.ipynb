# %%
print('hell')
# Out:
# hell

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


arr1 = {
    'name':['aslam','amir','piar','eman'],
    'age':[22,21,42,24]
}
df1 = pd.DataFrame(arr1)

print(df1)
# Out:
#     name  age
# 0  aslam   22
# 1   amir   21
# 2   piar   42
# 3   eman   24

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


arr1 = [1,2,3]
df1= pd.Series(arr1,index=(1,2,3))
print(df1)
# Out:
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

arr  = np.array([1,2,3,4])
print(arr)

dd = plt.plot(arr)
plt.show(dd)
# Out:
# [1 2 3 4]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5,6])

y =np.array([10,20,30,40,50,60])

z = np.array([1,2,3,4,5,6])

df = plt.plot(x,y,z,marker='*',mec = 'g',ms = 20)
plt.savefig('file.pdf')
plt.show(df)

# %%
df= pd.read_csv('financial.csv', nrows=11)

year = df['Year']
value= df['Value']

graph = plt.plot(year,value, marker="o")

plt.show(graph)
# print(df.head(4))

# %%
arr= {
    'name':['ali','ahmed','najam'],
    'age':[11,22,33],
    'height': [2,4,5]
}

df = pd.DataFrame(arr, index=['one','two','three'])

# value= df['name'][1]

print(df.ndim)
# Out:
# 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

arr = {
    'name':['hoor','eman'],
    'age' : [22,23],
    'edu':['bs math','bs eng'],
    'hight':[5,6]
}


df = pd.DataFrame(arr)
print(df.ndim)
# Out:
# 2

# %%
arr = [1,2,3,4,6]
ds = pd.Series(arr,index=[2,3,4,5,6])
print(ds)
# Out:
# 2    1
# 3    2
# 4    3
# 5    4
# 6    6
# dtype: int64

# %%
x = [10,20,30,40]
y = [1,2,3,4]

pl = plt.plot(x,y,marker = 'o',ms= 15,mec = 'r')
print(pl)

plt.savefig('file.pdf')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


md = pd.read_csv('mobile_sales_data.csv',usecols=['Product','Brand','Price','Inward Date'])
print(md.head(3))

b = md['Brand']
p = md['Price']


graph = plt.plot('b','p',marker = '*', mec = 'r' ,ms = 16)
print(graph)
# Out:
#         Product     Brand   Price Inward Date
# 0  Mobile Phone  Motorola   78570  2023-08-02
# 1        Laptop      Oppo   44613  2023-10-03
# 2  Mobile Phone   Samsung  159826  2025-03-19
# ...
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7896\1781720463.py:13: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "p" (-> marker='p'). The keyword argument will take precedence.
#   graph = plt.plot('b','p',marker = '*', mec = 'r' ,ms = 16)

# %%
import pandas as pd

# %%
name = ['hoor','noor','nehml']
age = [22,12,11]
dic={'name':name,'age':age}
df = pd.DataFrame(dic)

df.to_csv('./data/details.csv')

pd.read_csv('./data/details.csv')

df.describe()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
import pandas as pd

df = pd.read_csv('world_population.csv',usecols=['Rank','CCA3'],nrows = 10)
print(df)
# Out:
#    Rank CCA3
# 0    36  AFG
# 1   138  ALB
# 2    34  DZA
# 3   213  ASM
# 4   203  AND
# 5    42  AGO
# 6   224  AIA
# 7   201  ATG
# 8    33  ARG
# 9   140  ARM

# %%
import numpy as np
import matplotlib.pyplot as plt

r = df['Rank']
c = df['CCA3']

bar_colors = ['blue', 'red', 'red', 'red', 'green', 'blue', 'red', 'orange', 'red', 'blue']


plt.bar(c, r, width=0.3, color= bar_colors)
plt.show()

# %% [markdown]
# mean,median,mode

# %%
import pandas as pd

dic = {
    'salary' : [10000,20000,30000]
}

df = pd.DataFrame(dic)
df

df.mean()

df.median()

df.mode()
# Out:
#    salary
# 0   10000
# 1   20000
# 2   30000

# %% [markdown]
# plot.bar

# %%
import matplotlib.pyplot as plt

x = ['python','ML','DL','NLP']
y  = [80,90,95,89]

plt.xlabel('languages')
plt.ylabel('marit')
plt.title('languages marit',fontsize= 21)



c = ['m','r','b','y']


plt.bar(x,y,width = 0.2 , color = c ,edgecolor='r',align = 'edge',linewidth = 5)

plt.legend(['marit'])

plt.show()

# %%
x= ('UK','USA','PAK','IND')
y= np.array([2,3,4,7])
z= np.array([3,2,5,1])

width=0.3

p = np.arange(len(x))

p1= [i+width for i in p]

plt.bar(x,y, width=0.3)
plt.bar(p1,z, width= 0.3)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
flavours = ['Vanilla', 'Strawberry', 'Chocolate', 'MintChocolate', 'Others']
Frequency = [16,15,5,12,3]

c = ['r','y'] 

plt.bar(flavours,Frequency,width = 0.5,color = c)

plt.title('icecreme score')
plt.xlabel('FL')
plt.ylabel('FQ')

plt.show()

# %%
x = ["math", "biology", "chemistry"]
a = [50, 60, 70]
b = [20, 20, 30]
c = [78, 45, 67]
d = [56, 34, 12]

width = 0.2

x_pos = np.arange(len(x))  # [0, 1, 2]

# Plotting 4 bars side by side
plt.bar(x_pos, a, width=width, label='a')
plt.bar(x_pos + width, b, width=width, label='b')
plt.bar(x_pos + 2*width, c, width=width, label='c')
plt.bar(x_pos + 3*width, d, width=width, label='d')

# Fix x-axis labels to align with grouped bars
plt.xticks(x_pos + 1.5*width, x)

plt.xlabel("Subjects")
plt.ylabel("Scores")
plt.title("Scores by Subject")
plt.legend()
# plt.grid(True)
plt.show()

# %% [markdown]
# scatter plot

# %%
x = [10,20,30,40,50]
y = ['python','java','javascript','sqi','llm']
z = [20,40,90,19,50]
z1 = [0,90,20,40,100]

plt.scatter(x,y,color = 'red')
plt.scatter(z,y,color = 'purple')
plt.scatter(z1,y,color = 'blue')


plt.show()

# %% [markdown]
# histogram plot

# %%
x = [10,20,30,40,50]
plt.hist(x)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Hp\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ML PRDICTIONS

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


house= pd.
