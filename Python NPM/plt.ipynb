# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x= np.array([1,2,3,4,5,6,7])
y=np.array([2,5,6,8,2,4,7])
z=np.array([1,2,4,7])

graph= plt.plot(x,y,z,marker='*',ms=20, mec='b', mfc='yellow')
# y=np.array([1,2,3,4,7])
# graph2= plt.plot(y, marker='o')

plt.title('Sample')

# plt.savefig('graph.jpg')
#upscaler 
# plt.show(graph)
# Out:
# Text(0.5, 1.0, 'Sample')

# %%
country= ['USA','UK','Germany','ALG']
rank=np.array([1,5,3,4])

plt.bar(country,rank,)

plt.show()

# %%
# bar in horizontal
languages= ['Javascript','Python','Node','React','C++']
rank=np.array([5,4,3,2,1])

z=np.array([1,5,3,4,9])
plt.barh(languages,rank)
# plt.barh(rank,z)/

plt.show()

# %%
y= np.array([1,2,3,4,5])
z= np.array([4,5,3,4,9])

width= 0.2
p = np.arange(len(languages))
p1= [i+width for i in p]

plt.bar(languages,y, width,color='b' )
plt.bar(p1,z, width,color='r' )

plt.xticks([i+width/2 for i in range(len(languages))], languages)

plt.legend(['y','z'])
plt.show()

# %%
languages= ['Javascript','Python','Node','React','C++']

# Data for 4 groups
y = np.array([1, 2, 3, 4, 5])
z = np.array([4, 5, 3, 4, 9])
a = np.array([3, 6, 3, 1, 9])
b = np.array([0, 5, 7, 1, 3])

# Bar width and positions
width = 0.2
x = np.arange(len(languages))  # base positions

# Plot 4 bars side by side
plt.bar(x, y, width, label='y', color='b')
plt.bar(x + width, z, width, label='z', color='r')
plt.bar(x + 2*width, a, width, label='a', color='g')
plt.bar(x + 3*width, b, width, label='b', color='purple')

# Center x-axis labels under grouped bars
plt.xticks(x + 1.5*width, languages)

# Add legend and title
plt.xlabel("Languages")
plt.ylabel("Values")
plt.title("Grouped Bar Chart with 4 Bars")
plt.legend()

# Show the plot
plt.show()

# %%
xLabels= ['USA','UK','Germany']

arr= {
    'x': [1,2,3,],
    'y': [2,5,6],
    # 'z': [1,2,4]
}

fig,ax= plt.subplots()
bottom= np.zeros(3)
# for r,c in arr.items():
#     print(c)
width=0.6
for r,c in arr.items():
    p=ax.bar(xLabels,c, label=r,width=width ,bottom=bottom)
    bottom+=c

    ax.bar_label(p, label_type='center',)
plt.legend()

plt.show()

# %%
# Assignment

data= pd.read_csv('../CSV/world_population.csv', nrows= 50)

# print(data.columns)
# rows= data.head(2)
rank= data['Rank']
country= data['CCA3']
# population= data['2022 Population']
# wpp= data['World Population Percentage']
plt.figure(figsize=(15, 20))
bar_colors = ['tab:red', 'tab:blue', 'tab:pink', 'tab:orange']
# labels
# plt.ylabel('Rank',fontsize=20)
# plt.xlabel('Country',fontsize=20)
plt.title('World Population')
plt.xticks(rotation=45)

# 

# plt.bar(country,rank, color=bar_colors)
plt.barh(country,rank, color=bar_colors)
# plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Assignment
# ----> 3 data= pd.read_csv('../CSV/world_population.csv', nrows= 50)
#       5 # print(data.columns)
#       6 # rows= data.head(2)
#       7 rank= data['Rank']
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../CSV/world_population.csv'

# %%
# Scatter Graph
# Univariate = 1 variable
# Bivariate = 2 variable
# Multivariate = More than 2 variable
x=['Python','Java','C++','JavaScript','PHP','Ruby','Swift']
y= np.array([1,0,3,5,6,6,7])
z= np.array([4,5,4,7,6,9,7])
z1= np.array([7,6,4,6,5,3,2])
plt.scatter(x,y, marker='o',s=190, c='red', )

plt.scatter(x,z, marker='o',s=50, c='blue', )
plt.scatter(x,z1, marker='o',s=50, c='green', )
plt.show()

# %%
# Trend of Programming Languages

languages= ['Python','Java','C++','JavaScript','PHP','Ruby','Swift']
percentage= np.array([12.3,5.5,3.2,5.6,7.8,9.0,10.1])
fig, ax= plt.subplots()

y_pos= np.arange(len(languages))

bars= ax.barh(y_pos,percentage)
# labels
ax.set_yticks(y_pos)
ax.set_yticklabels(languages)
ax.bar_label(bars,fmt='%.1f%%')
ax.invert_yaxis()
ax.set_xticks([])
# ax.set_xlabel(0)
plt.tight_layout()
plt.show()

# %%
# Linear plot
# Bar plot
# Stem plot
# Step plot
# Hist plot
# Box plot
# Pie plot

# %%
# Stem Plot

x= np.array([1,2,3,4,5,6,7])
y= np.array([2,5,6,8,2,4,7])

plt.stem(x,y, markerfmt='ro', linefmt='b-')
plt.grid()
plt.show()

# %%
# Histogram plot

x= np.array([1,2,3,4,5,6,7])
y= np.random.randn(100)

plt.hist(x, color='blue', edgecolor='black')
# Out:
# (array([1., 1., 0., 1., 0., 1., 1., 0., 1., 1.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
# BoxPlot

x= np.array([1,2,3,4,5,6,7])

plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1839f000910>,
#   <matplotlib.lines.Line2D at 0x1839f000a50>],
#  'caps': [<matplotlib.lines.Line2D at 0x1839f000b90>,
#   <matplotlib.lines.Line2D at 0x1839f000cd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1839f0007d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1839f000e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1839f000f50>],
#  'means': []}

# %%
# Pie plot

languages= ['Python','Java','C++','JavaScript','PHP','Ruby','Swift']
percentage= np.array([12.3,5.5,3.2,5.6,7.8,9.0,10.1])

normalize= percentage / percentage.sum()

plt.pie(normalize, labels=languages, autopct=lambda p: f'{p * percentage.sum() / 100:.1f}%', startangle=140)
plt.show()
